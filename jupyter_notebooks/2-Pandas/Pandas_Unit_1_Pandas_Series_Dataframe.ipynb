# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png" width="25%" height="25%" />
#
# # Pandas - Unit 01 - Pandas Series and DataFrame
#
# ## <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%201%20-%20Lesson%20Learning%20Outcome.png"> Lesson Learning Outcome
#
# **Pandas Lesson is made of 17 units.**
# * By the end of this lesson, you should be able to:
#   * Understand **DataFrames** and how to read/save data
#   * **Explore and manipulate** your dataset
#   * **Group** and **Transform** data
#   * Understand Time Series
#   * **Visualize** data with Pandas
#
# ---
#
# ## <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%202%20-%20Unit%20Objective.png"> Unit Objectives
#
# * Understand Pandas Series and Pandas DataFrames
#
# ---
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%207-%20Note.png"> Pandas stands for *Panel Data*, which is an econometrics term for datasets that have observations over time for the same individuals. Nowadays a panel is not often used in Pandas for Data Science projects; DataFrames are most used.
# * Pandas was first released in 2008 and is used to **analyze and manipulate** data. It is considered one of the most important libraries in Data Science!
# * Pandas is built on top of NumPy. A lot of NumPy's structure is used or replicated on it.
#
# **Why do we use Pandas?**
#   * For data analysis, data exploration, data manipulation, data visualization. This is the **backbone** of any data science project.
#   * Pandas is used **for data manipulation** and to help clean messy data sets and make them readable and relevant
#
# ## <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%203%20-%20Additional%20Learning%20Context.png"> Additional Learning Context
#
# We encourage you to:
#   * Add **code cells and try out** other parameters values in a function/method, or consider additional function parameters etc.
#   * Also, **add your comment** in the cells. It can help you to consolidate the learning.
#
# Functions and Methods Parameters
#   * For any package presented in this course, we will not study in detail all possible functions/methods parameters. We will cover the most common parameters used in Data Science.
#   * You may seek additional information in the package documentation. The studied packages are open source
#   * **For Pandas the link is [here](https://pandas.pydata.org/)**.
#
# ---
#
# ## <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%204%20-%20Import%20Package%20for%20Learning.png"> Import Package for Learning
#
# import numpy as np
# import pandas as pd
#
# ---
#
# ## <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%2010-%20Lesson%20Content.png"> Pandas Series and DataFrame
#
# In this notebook we will cover
#   * What a Pandas Series is and how to creae one with `pd.Series()`
#   * What a Pandas DataFrame is and how to create one with `pd.DataFrame()`
#
# ![image.png](data:image/png;base64,...)
#
# ### <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%2010-%20Lesson%20Content.png"> Pandas Series
#
# In Data Science, Pandas handles data in Series and DataFrames.
#   * A **Pandas Series** is similar to a NumPy array:
#     * A grid of values that contain data (numerical, categorical, date, boolean etc)
#   * A key difference is that a Series can be `indexed` by a label, either number or category.
#
# Consider the Python lists, NumPy array and Python dictionary below. We will use them to create Pandas Series.
#
# categories = ['a','b','c']
# categories
#
# my_list = [-1,-2,-3]
# my_list
#
# arr = np.array([100,99,98])
# arr
#
# my_dict = {'Item1': 999, 'Item2': 888, 'Item3':777}
# my_dict
#
# There are multiple ways to create a Pandas Series
# * You can create a Pandas Series using `pd.Series()` based on a Python list. The argument is `data`
#   * The function documentation can be found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html)
#   * Note the list values (-1,-2,-3) and the indices (from 0 to 2)
#
# pd.Series(data=my_list)
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : Create a Series using `categories` list
#
# Your output should look like
#
#
#
# ```
# 0    a
# 1    b
# 2    c
# dtype: object
# ```
#
#
#
# # write your code here
# pd.Series(data=categories)
#
# You can use the same list for data argument, and use "`categories`" as the "`index`" for your Series
#   * Note the list values (-1,-2,-3) and the indices made based on categories variables (a,b,c)
#
# pd.Series(data=my_list,index=categories)
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : create a series where your data is `categories` and index is `my_list`
#
# Your output should look like
#
#
#
# ```
# -1    a
# -2    b
# -3    c
# dtype: object
# ```
#
#
#
# # write your code here
# pd.Series(data=categories,index=my_list)
#
# ---
#
# You can also assign a name for your Series using the argument "`name`"
#
# pd.Series(data=my_list,index=categories,name="My First Series")
#
# As you noticed in a previous practice, Series values can handle multiple data types, including numerical, categorical, date/time. In the example below, the data is categorical (a,b,c), and the index is numerical (0,1,2).
#
# pd.Series(data=categories)
#
# You can use a NumPy array to create a Series also
# * Let's recap `arr` content first
#
# arr
#
# *We* parse/add into `pd.Series()`
#
# pd.Series(data=arr)
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : create a Series where your data is `arr`, index is `categories` and name is `Series with array`
#
#   * You will notice that the index can handle multiple data types, that includes numerical, categorical, date/time.
#
# Your output should look like this
#
#
#
# ```
# a    100
# b     99
# c     98
# Name: Series with array, dtype: int64
# ```
#
#
#
# # write your code here
# pd.Series(data=arr,index=categories,name="Series with array")
#
# ---
#
# You can create a Series with a dictionary. In this case, you don't need to parse the index argument, since the dictionary structure (`key:value`) will correspond to index and value in the Series
#
# pd.Series(data=my_dict)
#
# In the workplace, the nomenclature for Pandas Series will typically be **ser**, or **series**.
#
# ser = pd.Series(data=my_dict)
# ser
#
# ---
#
# ### <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%2010-%20Lesson%20Content.png"> Pandas DataFrame
#
# **DataFrames** are the basis of Pandas.
#   * A dataframe is a **set of Series** put together to **share the same index**.
#   * Think of DataFrames as an Excel, or data table in JavaScript
#   * Typically the nomenclature for a Pandas DataFrame is **df**
#
#
# To create a DataFrame, use `pd.DataFrame()`. Consider the DataFrame below created based on the following arguments:
#   * `data` is an array.
#   * `index` is a list A to E
#   * `columns` a list Col1 to Col4
#   * The function documentation can be found [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)
#
# np.random.seed(101)
# df = pd.DataFrame(data=np.random.randn(5,4),
#                   index=['A', 'B', 'C', 'D', 'E'],
#                   columns=['Col1', 'Col2', 'Col3', 'Col4']
#                   )
# df
#
# If you just write the DataFrame variable - in this case `df` - and run the cell, you will **display** the DataFrame.
# * Note how the DataFrame was displayed in a nice table format. You can hover over the rows if you want to
#
# ---
#
# We consider now a second dictionary: `dict1`
#   * The values are numbers saved in a list
#
# dict1 = {'Item1':[9,9,7,1], 'Item2':[8,6,68,8], 'Item3':[1,2,7,8]}
# dict1
#
# If you now create a Pandas DataFrame, named `df`,  from a dictionary the dictionary `keys` will be the DataFrame columns and the dictionary values will be the DataFrame values. The Index will be numeric starting from 0.
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : check yourself that, parse `dict1` as the data `argument` in the function `pd.DataFrame()`.
#
# Your output content should look like
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# # write your code here
# df=pd.DataFrame(data=dict1)
# df
#
# ---
#
# You can print a DataFrame using `print()`. It will look different than the previous view.
#   * In practical terms, we tend **not** to print DataFrames with `print()`, since the rows/columns may be cluttered when there is more data
#
# * The DataFrame below has 10 rows and 40 columns and is made with NumPy array
#   * If you just write `df` and run the cell you can check all content
#
# np.random.seed(101)
# df = pd.DataFrame(data=np.random.randn(10,40))
# df
#
# * When you `print()` the `df`, the majority of columns are cluttered.
#
# print(df)
#
# ---
#
# * `.copy()`
#   * You can create a copy of  your DataFrame using **.copy()**. This is useful when you want to have a script/logic and want to process your DataFrame and keep the original; so you create a copy
#
# df2 = df.copy()
#
# df2
#
# ---
