# %% [markdown]
# <img src="https://raw.githubusercontent.com/numpy/numpy/181f273a59744d58f90f45d953a3285484c72cba/branding/logo/primary/numpylogo.svg" width="25%" height="25%" />
#
# # NumPy - Unit 08 - Operations and Universal Functions
#
# ## <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%202%20-%20Unit%20Objective.png"> Unit Objectives
#
# * Run NumPy **operations and use universal functions**
#
#
# ## <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%204%20-%20Import%20Package%20for%20Learning.png"> Import Package for Learning
#
# import numpy as np
#
# ## <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%2010-%20Lesson%20Content.png"> Operations and Universal Functions
#
# ![image.png](data:image/png;base64,...)
#
# ---
#
# Consider two distinct arrays with same dimension: **arr1** and **arr2**, both made with np.random.randint()
#
# np.random.seed(seed=2)
# arr1 = np.random.randint(low=0,high=8,size=(3,5))
# arr1
#
# np.random.seed(seed=1)
# arr2 = np.random.randint(low=0,high=50,size=(3,5))
# arr2
#
# NumPy arrays allow operations
# * You can sum a constant to a numeric array
#
# arr2 + 2
#
# You can divide the array by a constant
#
# arr1 / 7
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : Try yourself to multiply or subtract an array by a constant number, either integer or float.
#
# arr1 * 1.5 # replace the dots for a constant number, either integer (like 1) or float (like 1.5 or 1.0)
#
# arr1 - 1.2 # replace the dots for a constant number, either integer (like 1) or float (like 1.5 or 1.0)
#
# You can use the arithmetic operator exponentiation in an array, in this case, arr1 to the power of 3
#
# arr1**3
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : make arr1 to the power of 2
#
#
# Your output should look like this
#
#
#
# ```
# array([[ 0, 49, 25,  0, 36],
#        [ 9,  4,  9,  0, 49],
#        [ 4,  1, 49,  9, 25]])
# ```
#
#
#
#
# # write your code here
# arr1**2
#
# You can run operations between arrays, like sum
#
# arr1 + arr2
#
# Or multiplication
#
# arr1 * arr2
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : subtract arr1 from arr2 in the cell below
#   *  use the "-" (minus) operator,
#
# Your output should look like this
#
#
#
# ```
# array([[37, 36,  7,  8,  3],
#        [ 8,  3, 12,  0,  9],
#        [-1, 11,  0, 42,  1]])
# ```
#
#
#
#
# # write your code here
# arr2-arr1
#
# Or division
# * In this case, **when the numerator and denominator elements are zero**, the operation's result for that element is **nan** (not a number).
# * You can check that on the 2nd row, 4th column
#
# arr1/arr2
#
# Another use case, **when the denominator element is zero**, the operation's result for that element is **inf** (infinite).
#   * You can check that on the 2nd row, 4th column
#
# 1/arr2
#
# ---
#
# Universal functions in NumPy  are simply mathematical functions, you can check the full list [here](https://numpy.org/doc/stable/reference/ufuncs.html).
# * Consider the array **arr** below
#
# np.random.seed(seed=101)
# arr = np.random.randint(low=-10,high=25,size=(3,5))
# arr
#
# You can get the square root of each element using `np.sqrt()`
#   * Note when the element is negative, the square root is nan (not a number), considering the "land of the real numbers".
#
# np.sqrt(arr)
#
# Or the absolute value of each element with `np.abs()`
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : get absolute value of each arr element
#
# Your output should look like
#
#
#
# ```
# array([[21,  1,  7,  4, 13],
#        [ 1,  1,  3,  6, 18],
#        [10,  5,  2, 19,  9]])
# ```
#
#
#
# # write your code here
# np.abs(arr)
#
# Or calculate the exponential in base 2 (2 ** x) of all elements
#
#
# np.exp2(arr)
#
# Calculate the natural logarithm for each element, using **np.log()**
#
# np.log(arr)
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : calculate the base-2 logarithm for each element using `np.log2()`
#
# Your output should look like
#
#
#
# ```
# array([[4.39231742, 0.        , 2.80735492,        nan, 3.70043972],
#        [0.        ,        nan, 1.5849625 ,        nan, 4.169925  ],
#        [       nan,        nan, 1.        , 4.24792751, 3.169925  ]])
# ```
#
# # write your code here
# np.log2(arr)
#
# Or you calculate the base-10 logarithm for each element using `np.log10()`
#
# np.log10(arr)
#
# ---
#
# You can start calculating some statistics measures.
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : Calculate the standard deviation for the array using `np.std()`
#
#
# Your output should be 9.344279295673667
#
#
# # write here your code
# np.std(arr)
#
# You can calculate the mean for the array using `np.mean()`
#
# np.mean(arr)
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : Calculate the median for the array using `np.median()`
#
#
# Your output should be 2.0
#
# # write here your code
# np.median(arr)
#
# Calculate the max value for the array
#
# np.max(arr)
#
# And the min value
#
# np.min(arr)
#
# You can get the sum off all values in the array with np.sum()
#
# np.sum(arr)
#
# ---
#
# A quick recap in your array content
#
# arr
#
# You can get the sum of all the columns in the array, using `np.sum()` and setting `axis= 0`
# * Before running the code below, imagine how this function would work and what would be the answer. Were you accurate?
#
# np.sum(arr,axis=0)
#
# <img width="3%" height="3%" align="top"  src="https://codeinstitute.s3.amazonaws.com/predictive_analytics/jupyter_notebook_icons/Icon%205%20-%20Practice.png"> **PRACTICE** : Or you can get the sum of all the rows in the array,  using `np.sum()` and setting `axis= 1`. Try yourself
#
#
# Your output should look like
#
#
#
# ```
# array([38, 15, 15])
# ```
#
#
#
# # write your code here
# np.sum(arr,axis=1)
#
# ---
